# %%
import ROOT
import my_library.constants as constants
import my_library.common_analysis_tools as ct
import my_library.kinematic_cuts as kcuts
# Out:
# Welcome to JupyROOT 6.24/04

# %%
run_period = 'spring'
data_type = 'data'

# %%
df_pipkmks = ct.get_dataframe('pipkmks', run_period, data_type)
df_pimkpks = ct.get_dataframe('pimkpks', run_period, data_type)

# %%
df_pipkmks = df_pipkmks.Filter(kcuts.KSTAR_ALL_CUT_PIPKMKS).Filter('pipkmks_m > 1.1 && pipkmks_m < 1.35')
df_pimkpks = df_pimkpks.Filter(kcuts.KSTAR_ALL_CUT_PIMKPKS).Filter('pimkpks_m > 1.1 && pimkpks_m < 1.35')

# %%
df_pipkmks = df_pipkmks.Define('ppip2_px', 'p_px + pip2_px').Define('ppip2_py', 'p_py + pip2_py').Define('ppip2_pz', 'p_pz + pip2_pz') \
                       .Define('ppip2_E', 'p_E + pip2_E').Define('ppip2_m', 'sqrt(ppip2_E*ppip2_E - ppip2_px*ppip2_px - ppip2_py*ppip2_py - ppip2_pz*ppip2_pz)') \
                       .Define('ppim_px', 'p_px + pim_px').Define('ppim_py', 'p_py + pim_py').Define('ppim_pz', 'p_pz + pim_pz') \
                       .Define('ppim_E', 'p_E + pim_E').Define('ppim_m', 'sqrt(ppim_E*ppim_E - ppim_px*ppim_px - ppim_py*ppim_py - ppim_pz*ppim_pz)') \
                        .Define('kmpip2_px', 'km_px + pip2_px').Define('kmpip2_py', 'km_py + pip2_py').Define('kmpip2_pz', 'km_pz + pip2_pz') \
                        .Define('kmpip2_E', 'km_E + pip2_E').Define('kmpip2_m', 'sqrt(kmpip2_E*kmpip2_E - kmpip2_px*kmpip2_px - kmpip2_py*kmpip2_py - kmpip2_pz*kmpip2_pz)') \
                        .Define('kmpim_px', 'km_px + pim_px').Define('kmpim_py', 'km_py + pim_py').Define('kmpim_pz', 'km_pz + pim_pz') \
                        .Define('kmpim_E', 'km_E + pim_E').Define('kmpim_m', 'sqrt(kmpim_E*kmpim_E - kmpim_px*kmpim_px - kmpim_py*kmpim_py - kmpim_pz*kmpim_pz)') \
                        .Define('kspip2_px', 'ks_px + pip2_px').Define('kspip2_py', 'ks_py + pip2_py').Define('kspip2_pz', 'ks_pz + pip2_pz') \
                        .Define('kspip2_E', 'ks_E + pip2_E').Define('kspip2_m', 'sqrt(kspip2_E*kspip2_E - kspip2_px*kspip2_px - kspip2_py*kspip2_py - kspip2_pz*kspip2_pz)') \
                        .Define('kspim_px', 'ks_px + pim_px').Define('kspim_py', 'ks_py + pim_py').Define('kspim_pz', 'ks_pz + pim_pz') \
                        .Define('kspim_E', 'ks_E + pim_E').Define('kspim_m', 'sqrt(kspim_E*kspim_E - kspim_px*kspim_px - kspim_py*kspim_py - kspim_pz*kspim_pz)')

df_pimkpks = df_pimkpks.Define('ppim2_px', 'p_px + pim2_px').Define('ppim2_py', 'p_py + pim2_py').Define('ppim2_pz', 'p_pz + pim2_pz') \
                        .Define('ppim2_E', 'p_E + pim2_E').Define('ppim2_m', 'sqrt(ppim2_E*ppim2_E - ppim2_px*ppim2_px - ppim2_py*ppim2_py - ppim2_pz*ppim2_pz)') \
                        .Define('kppim2_px', 'kp_px + pim2_px').Define('kppim2_py', 'kp_py + pim2_py').Define('kppim2_pz', 'kp_pz + pim2_pz') \
                        .Define('kppim2_E', 'kp_E + pim2_E').Define('kppim2_m', 'sqrt(kppim2_E*kppim2_E - kppim2_px*kppim2_px - kppim2_py*kppim2_py - kppim2_pz*kppim2_pz)') \
                        .Define('kppip_px', 'kp_px + pip_px').Define('kppip_py', 'kp_py + pip_py').Define('kppip_pz', 'kp_pz + pip_pz') \
                        .Define('kppip_E', 'kp_E + pip_E').Define('kppip_m', 'sqrt(kppip_E*kppip_E - kppip_px*kppip_px - kppip_py*kppip_py - kppip_pz*kppip_pz)') \
                        .Define('kspim2_px', 'ks_px + pim2_px').Define('kspim2_py', 'ks_py + pim2_py').Define('kspim2_pz', 'ks_pz + pim2_pz') \
                        .Define('kspim2_E', 'ks_E + pim2_E').Define('kspim2_m', 'sqrt(kspim2_E*kspim2_E - kspim2_px*kspim2_px - kspim2_py*kspim2_py - kspim2_pz*kspim2_pz)') \
                        .Define('kspip_px', 'ks_px + pip_px').Define('kspip_py', 'ks_py + pip_py').Define('kspip_pz', 'ks_pz + pip_pz') \
                        .Define('kspip_E', 'ks_E + pip_E').Define('kspip_m', 'sqrt(kspip_E*kspip_E - kspip_px*kspip_px - kspip_py*kspip_py - kspip_pz*kspip_pz)')

                        # .Define('ppip_px', 'p_px + pip_px').Define('ppip_py', 'p_py + pip_py').Define('ppip_pz', 'p_pz + pip_pz') \
                        # .Define('ppip_E', 'p_E + pip_E').Define('ppip_m', 'sqrt(ppip_E*ppip_E - ppip_px*ppip_px - ppip_py*ppip_py - ppip_pz*ppip_pz)')

# %%
hist_ppip2_m = df_pipkmks.Histo1D(('hist_ppip2_m', 'M(p#pi^{+}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 50, 1.0, 3.0), 'ppip2_m')
hist_ppim_m = df_pipkmks.Histo1D(('hist_ppim_m', 'M(p#pi^{-}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 50, 1.0, 3.0), 'ppim_m')
hist_ppim2 = df_pimkpks.Histo1D(('hist_ppim2_m', 'M(p#pi^{-}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 50, 1.0, 3.0), 'ppim2_m')
hist_ppip = df_pimkpks.Histo1D(('hist_ppip_m', 'M(p#pi^{+}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 50, 1.0, 3.0), 'ppip_m')

# %%
c1 = ROOT.TCanvas('c1', 'c1', 1200, 1000)
c1.Divide(2,2)

# %%
c1.cd(1)
hist_ppip2_m.Draw()
c1.cd(2)
hist_ppim_m.Draw()
c1.cd(3)
hist_ppim2.Draw()
c1.cd(4)
hist_ppip.Draw()
c1.Draw()

# %%
hist_ppip2_2d_m = df_pipkmks.Histo2D(('hist_ppip2_m', 'M(p#pi^{+}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 20, 1.2, 1.35, 50, 1.0, 3.0), "pipkmks_m",  'ppip2_m')
hist_ppim_2d_m = df_pipkmks.Histo2D(('hist_ppim_m', 'M(p#pi^{-}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 20, 1.2, 1.35, 50, 1.0, 3.0), "pipkmks_m",  'ppim_m')
hist_ppim2_2d_m = df_pimkpks.Histo2D(('hist_ppim2_m', 'M(p#pi^{-}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 20, 1.2, 1.35, 50, 1.0, 3.0), "pimkpks_m",  'ppim2_m')
hist_ppip_2d_m = df_pimkpks.Histo2D(('hist_ppip_m', 'M(p#pi^{+}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 20, 1.2, 1.35, 50, 1.0, 3.0), "pimkpks_m",  'ppip_m')

# %%
c1.cd(1)
hist_ppip2_2d_m.Draw('colz')
c1.cd(2)
hist_ppim_2d_m.Draw('colz')
c1.cd(3)
hist_ppim2_2d_m.Draw('colz')
c1.cd(4)
hist_ppip_2d_m.Draw('colz')
c1.Draw()

# %%
hist_kpip2_m = df_pipkmks.Histo1D(('hist_kpip2_m', 'M(K^{-}#pi^{+}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 80, 0.6, 1.0), 'kmpip2_m')
hist_kpim_m = df_pipkmks.Histo1D(('hist_kpim_m', 'M(K^{-}#pi^{-}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 80, 0.6, 1.0), 'kmpim_m')
hist_kpim2 = df_pimkpks.Histo1D(('hist_kpim2_m', 'M(K^{+}p#pi^{-}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 80, 0.6, 1.0), 'kppim2_m')
hist_kpip = df_pimkpks.Histo1D(('hist_kpip_m', 'M((K^{+}#pi^{+}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 80, 0.6, 1.0), 'kppip_m')

# %%
c1.cd(1)
hist_kpip2_m.Draw()
c1.cd(2)
hist_kpim_m.Draw()
c1.cd(3)
hist_kpim2.Draw()
c1.cd(4)
hist_kpip.Draw()
c1.Draw()

# %%
hist_kpip2_2d_m = df_pipkmks.Histo2D(('hist_kpip2_m', 'M(K^{-}#pi^{+}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 20, 1.2, 1.35, 80, 0.6, 1.0), "pipkmks_m",  'kmpip2_m')
hist_kpim_2d_m = df_pipkmks.Histo2D(('hist_kpim_m', 'M(K^{-}#pi^{-}_{K_{s}}) for #pi^{+}K^{-}K_{s}', 20, 1.2, 1.35, 80, 0.6, 1.0), "pipkmks_m",  'kmpim_m')
hist_kpim2_2d_m = df_pimkpks.Histo2D(('hist_kpim2_m', 'M(K^{+}#pi^{-}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 20, 1.2, 1.35, 80, 0.6, 1.0), "pimkpks_m",  'kppim2_m')
hist_kpip_2d_m = df_pimkpks.Histo2D(('hist_kpip_m', 'M(pK^{+}pi^{+}_{K_{s}}) for #pi^{-}K^{+}K_{s}', 20, 1.2, 1.35, 80, 0.6, 1.0), "pimkpks_m",  'kppip_m')

# %%
c1.cd(1)
hist_kpip2_2d_m.Draw('colz')
c1.cd(2)
hist_kpim_2d_m.Draw('colz')
c1.cd(3)
hist_kpim2_2d_m.Draw('colz')
c1.cd(4)
hist_kpip_2d_m.Draw('colz')
c1.Draw()
