# %%
import ROOT
import my_library.common_analysis_tools as ct
# Out:
# Welcome to JupyROOT 6.24/04

# %%
file_and_tree = ct.get_flat_file_and_tree('pipkmks', 'spring', 'signal')

# %%
df = ROOT.RDataFrame(file_and_tree[1], file_and_tree[0])

# %%
df.Display(['mand_t', 't_bin'], nRows=200).Print()
# Out:
# mand_t     | t_bin |
# 0.30111439 | 3     |
# 0.23331706 | 2     |
# 0.35196660 | 3     |
# 0.54687753 | 4     |
# 0.59721056 | 4     |
# 0.22270161 | 2     |
# 0.32849014 | 3     |
# 0.16362287 | 1     |
# 0.68696474 | 5     |
# 0.20302698 | 2     |
# 0.30487162 | 3     |
# 0.32447857 | 3     |
# 0.35260576 | 3     |
# 0.40417350 | 4     |
# 0.34540675 | 3     |
# 0.43963319 | 4     |
# 0.40708963 | 4     |
# 0.89011457 | 5     |
# 0.36812897 | 3     |
# 0.89462765 | 5     |
# 0.56548841 | 4     |
# 0.29698541 | 2     |
# 0.70828216 | 5     |
# 0.91610722 | 6     |
# 0.44776366 | 4     |
# 0.16729766 | 1     |
# 0.28828301 | 2     |
# 1.6059804  | 7     |
# 1.1530185  | 6     |
# 0.15665396 | 1     |
# 0.31674547 | 3     |
# 1.3914926  | 6     |
# 0.44291860 | 4     |
# 0.64127948 | 4     |
# 0.78414153 | 5     |
# 1.2032450  | 6     |
# 1.6543632  | 7     |
# 0.53237819 | 4     |
# 0.41544225 | 4     |
# 0.50595603 | 4     |
# 0.18856953 | 1     |
# 1.2225429  | 6     |
# ...
