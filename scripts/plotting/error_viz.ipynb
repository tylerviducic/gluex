# %%
import ROOT
import my_library.common_analysis_tools as tools
import my_library.kinematic_cuts as cuts
import my_library.constants as constants
import my_library.gluex_style as gxs
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Welcome to JupyROOT 6.24/04

# %%
df_cs_final_pipkmks = pd.read_csv('/work/halld/home/viducic/data/fit_params/pipkmks/cs_final.csv')
df_cs_final_pimkpks = pd.read_csv('/work/halld/home/viducic/data/fit_params/pimkpks/cs_final.csv')

df_cs_final_pipkmks = df_cs_final_pipkmks[['stat_error', 'fit_error', 'cut_error', 'sys_error', 'total_percent_error']]

# %%
fig, ax = plt.subplots(figsize=(10, 6))
labels = ['Statistical Uncertainty', 'Fit Systematic', 'Cut Systematic', 'Total Systematic', 'Total Uncertainty']
df_cs_final_pipkmks.columns = labels
sns.boxplot(data=df_cs_final_pipkmks, linewidth=3)
ax.set_ylabel("Relative Uncertainty", fontsize=14)
ax.set_xlabel("Uncertainty Source", fontsize=14)
# Out:
# Text(0.5, 0, 'Uncertainty Source')

# %%
norm_data = {
    'Monte Carlo': 0.27,
    'Tracking': 0.12,
    'Branching Fraction': 0.04,
    'Luminosity': 0.05,
    'Total': 0.3
}

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.bar(norm_data.keys(), norm_data.values())
ax.set_ylabel("Relative Uncertainty", fontsize=14)
ax.set_xlabel("Uncertainty Source", fontsize=14)
plt.show()
