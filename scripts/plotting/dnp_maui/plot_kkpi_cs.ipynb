# %%
import ROOT
import numpy as np
import pandas as pd
import my_library.gluex_style as gs
# Out:
# Welcome to JupyROOT 6.24/04

# %%
gluex_colors = {
    8: ROOT.kRed+1,
    9: ROOT.kBlue+1,
    10: ROOT.kMagenta+2,
    11: ROOT.kCyan+3
}

theory_colors = {
    8: ROOT.kRed-6,
    9: ROOT.kBlue-6,
    10: ROOT.kMagenta-6,
    11: ROOT.kCyan-6
}

clas_colors = {
    2.45: ROOT.kRed+3,
    2.55: ROOT.kBlue+3,
    2.65: ROOT.kMagenta+3,
    2.75: ROOT.kCyan+4,
}

gluex_markers = {
    8: ROOT.kFullCircle,
    9: ROOT.kFullSquare,
    10: ROOT.kFullTriangleUp,
    11: ROOT.kFullDiamond
}

clas_markers = {
    2.45: ROOT.kOpenDiamond,
    2.55: ROOT.kOpenSquare,
    2.65: ROOT.kOpenTriangleUp,
    2.75: ROOT.kOpenCircle
}

theory_markers = {
    8: ROOT.kFullDotLarge,
    9: ROOT.kFullDotLarge,
    10: ROOT.kOpenTriangleUp,
    11: ROOT.kOpenDiamond
}

# %%
pipkmks_binned_fit_results_filename = f'/work/halld/home/viducic/data/fit_params/pipkmks/tf1_cross_section_values.csv'
pimkpks_binned_fit_results_filename = f'/work/halld/home/viducic/data/fit_params/pimkpks/tf1_cross_section_values.csv'

pipkmks_df = pd.read_csv(pipkmks_binned_fit_results_filename)
pimkpks_df = pd.read_csv(pimkpks_binned_fit_results_filename)
pipkmks_df = pipkmks_df[pipkmks_df.beam_energy > 7]
pimkpks_df = pimkpks_df[pimkpks_df.beam_energy > 7]
print(pipkmks_df.to_markdown())
print(pimkpks_df.to_markdown())
# Out:
# |    |   mean |   mean_error |   width |   width_error |   chi2ndf |     yield |   yield_error |   acceptance |   acceptance_error |   cross_section |   cross_section_error |   t_bin_middle |   t_bin_width |   beam_energy |   luminosity |
# |---:|-------:|-------------:|--------:|--------------:|----------:|----------:|--------------:|-------------:|-------------------:|----------------:|----------------------:|---------------:|--------------:|--------------:|-------------:|
# |  0 | 1.2798 |            0 | 0.02771 |             0 |  1.13067  |  448.237  |      48.3853  |    0.0114066 |                  0 |       183.662   |             19.8256   |          0.15  |         0.05  |             8 |     141072   |
# |  1 | 1.2798 |            0 | 0.02771 |             0 |  1.20123  |  748.512  |      64.6251  |    0.0289535 |                  0 |       120.828   |             10.432    |          0.25  |         0.05  |             8 |     141072   |
# |  2 | 1.2798 |            0 | 0.02771 |             0 |  1.31443  |  670.547  |      58.6757  |    0.0307516 |                  0 |       101.913   |              8.91782  |          0.35  |         0.05  |             8 |     141072   |
# |  3 | 1.2798 |            0 | 0.02771 |             0 |  1.21447  | 1209.88   |      69.714   |    0.0305535 |                  0 |        74.0302  |              4.26567  |          0.525 |         0.125 |             8 |     141072   |
# |  4 | 1.2798 |            0 | 0.02771 |             0 |  1.69352  |  719.744  |      46.4773  |    0.0291526 |                  0 |        46.1561  |              2.98052  |          0.775 |         0.125 |             8 |     141072   |
# |  5 | 1.2798 |            0 | 0.02771 |             0 |  1.52567  |  664.34   |      37.2223  |    0.0255372 |                  0 |        24.3172  |              1.36247  |          1.15  |         0.25  |             8 |     141072   |
# |  6 | 1.2798 |            0 | 0.02771 |             0 |  1.00229  |  142.775  |      17.5342  |    0.0208624 |                  0 |         6.39714 |              0.785631 |          1.65  |         0.25  |             8 |     141072   |
# |  7 | 1.2798 |            0 | 0.02771 |             0 |  1.09432  |  315.693  |      40.5664  |    0.0113542 |                  0 |       163.245   |             20.9769   |          0.15  |         0.05  |             9 |     112300   |
# |  8 | 1.2798 |            0 | 0.02771 |             0 |  1.62744  |  572.93   |      58.9849  |    0.0294207 |                  0 |       114.335   |             11.7712   |          0.25  |         0.05  |             9 |     112300   |
# |  9 | 1.2798 |            0 | 0.02771 |             0 |  0.962167 |  442.694  |      49.5998  |    0.0316151 |                  0 |        82.2129  |              9.21122  |          0.35  |         0.05  |             9 |     112300   |
# | 10 | 1.2798 |            0 | 0.02771 |             0 |  1.35526  | 1005.63   |      61.4126  |    0.0320494 |                  0 |        73.6904  |              4.50017  |          0.525 |         0.125 |             9 |     112300   |
# | 11 | 1.2798 |            0 | 0.02771 |             0 |  1.22086  |  603.84   |      40.7432  |    0.0309241 |                  0 |        45.8581  |              3.09421  |          0.775 |         0.125 |             9 |     112300   |
# | 12 | 1.2798 |            0 | 0.02771 |             0 |  1.00151  |  339.301  |      30.0649  |    0.0279558 |                  0 |        14.252   |              1.26284  |          1.15  |         0.25  |             9 |     112300   |
# | 13 | 1.2798 |            0 | 0.02771 |             0 |  0.754103 |  101      |      15.5907  |    0.0229236 |                  0 |         5.17368 |              0.798626 |          1.65  |         0.25  |             9 |     112300   |
# | 14 | 1.2798 |            0 | 0.02771 |             0 |  1.13606  |  117.364  |      31.1227  |    0.0113284 |                  0 |        96.4677  |             25.5813   |          0.15  |         0.05  |            10 |      70810.1 |
# | 15 | 1.2798 |            0 | 0.02771 |             0 |  0.775092 |  386.351  |      44.4643  |    0.0292741 |                  0 |       122.889   |             14.143    |          0.25  |         0.05  |            10 |      70810.1 |
# | 16 | 1.2798 |            0 | 0.02771 |             0 |  1.18944  |  293.07   |      39.1523  |    0.0320267 |                  0 |        85.207   |             11.3831   |          0.35  |         0.05  |            10 |      70810.1 |
# | 17 | 1.2798 |            0 | 0.02771 |             0 |  0.948977 |  536.957  |      45.648   |    0.0335595 |                  0 |        59.5936  |              5.06619  |          0.525 |         0.125 |            10 |      70810.1 |
# | 18 | 1.2798 |            0 | 0.02771 |             0 |  1.60862  |  299.132  |      29.7396  |    0.0331031 |                  0 |        33.6564  |              3.34612  |          0.775 |         0.125 |            10 |      70810.1 |
# | 19 | 1.2798 |            0 | 0.02771 |             0 |  1.80461  |  203.045  |      23.8957  |    0.0308479 |                  0 |        12.2578  |              1.44258  |          1.15  |         0.25  |            10 |      70810.1 |
# | 20 | 1.2798 |            0 | 0.02771 |             0 |  1.17343  |   92.4147 |       2.07471 |    0.0268859 |                  0 |         6.40121 |              0.143707 |          1.65  |         0.25  |            10 |      70810.1 |
# | 21 | 1.2798 |            0 | 0.02771 |             0 |  1.4019   |   94.1658 |     105.901   |    0.0105796 |                  0 |        97.5853  |            109.746    |          0.15  |         0.05  |            11 |      60138   |
# | 22 | 1.2798 |            0 | 0.02771 |             0 |  1.20745  |  113.775  |      36.3349  |    0.02785   |                  0 |        44.7903  |             14.3041   |          0.25  |         0.05  |            11 |      60138   |
# | 23 | 1.2798 |            0 | 0.02771 |             0 |  1.26618  |  213.732  |      34.3593  |    0.0310002 |                  0 |        75.5903  |             12.1518   |          0.35  |         0.05  |            11 |      60138   |
# | 24 | 1.2798 |            0 | 0.02771 |             0 |  0.319195 |  373.09   |      40.9111  |    0.0332047 |                  0 |        49.276   |              5.40334  |          0.525 |         0.125 |            11 |      60138   |
# | 25 | 1.2798 |            0 | 0.02771 |             0 |  1.30329  |  241.986  |      25.4981  |    0.0334801 |                  0 |        31.6975  |              3.33997  |          0.775 |         0.125 |            11 |      60138   |
# | 26 | 1.2798 |            0 | 0.02771 |             0 |  1.76422  |  154.534  |      18.9415  |    0.0319812 |                  0 |        10.5955  |              1.2987   |          1.15  |         0.25  |            11 |      60138   |
# | 27 | 1.2798 |            0 | 0.02771 |             0 |  1.4021   |   92.4179 |       1.31193 |    0.0281917 |                  0 |         7.1883  |              0.102042 |          1.65  |         0.25  |            11 |      60138   |
# |    |   mean |   mean_error |   width |   width_error |   chi2ndf |     yield |   yield_error |   acceptance |   acceptance_error |   cross_section |   cross_section_error |   t_bin_middle |   t_bin_width |   beam_energy |   luminosity |
# |---:|-------:|-------------:|--------:|--------------:|----------:|----------:|--------------:|-------------:|-------------------:|----------------:|----------------------:|---------------:|--------------:|--------------:|-------------:|
# |  0 | 1.2843 |            0 | 0.02467 |             0 |  0.680323 |  507.099  |     44.6793   |    0.0117162 |                  0 |       202.29    |            17.8233    |          0.15  |         0.05  |             8 |     141072   |
# |  1 | 1.2843 |            0 | 0.02467 |             0 |  0.631812 | 1186.43   |     63.6541   |    0.0298267 |                  0 |       185.911   |             9.97446   |          0.25  |         0.05  |             8 |     141072   |
# |  2 | 1.2843 |            0 | 0.02467 |             0 |  1.27798  | 1148.92   |     58.9626   |    0.0316339 |                  0 |       169.748   |             8.71148   |          0.35  |         0.05  |             8 |     141072   |
# |  3 | 1.2843 |            0 | 0.02467 |             0 |  2.23321  | 2241.95   |     77.5046   |    0.0317125 |                  0 |       132.167   |             4.56904   |          0.525 |         0.125 |             8 |     141072   |
# |  4 | 1.2843 |            0 | 0.02467 |             0 |  0.960407 |  969.172  |     50.6243   |    0.0301044 |                  0 |        60.1865  |             3.14381   |          0.775 |         0.125 |             8 |     141072   |
# |  5 | 1.2843 |            0 | 0.02467 |             0 |  0.957155 |  613.13   |     38.551    |    0.0268469 |                  0 |        21.3479  |             1.34227   |          1.15  |         0.25  |             8 |     141072   |
# |  6 | 1.2843 |            0 | 0.02467 |             0 |  0.881541 |   93.6026 |    503.262    |    0.021144  |                  0 |         4.13808 |            22.2487    |          1.65  |         0.25  |             8 |     141072   |
# |  7 | 1.2843 |            0 | 0.02467 |             0 |  1.12978  |  409.596  |     40.7844   |    0.0117681 |                  0 |       204.353   |            20.348     |          0.15  |         0.05  |             9 |     112300   |
# |  8 | 1.2843 |            0 | 0.02467 |             0 |  1.54966  |  845.378  |     56.6315   |    0.0305114 |                  0 |       162.675   |            10.8975    |          0.25  |         0.05  |             9 |     112300   |
# |  9 | 1.2843 |            0 | 0.02467 |             0 |  1.1804   |  978.404  |     53.8413   |    0.0325901 |                  0 |       176.264   |             9.69976   |          0.35  |         0.05  |             9 |     112300   |
# | 10 | 1.2843 |            0 | 0.02467 |             0 |  0.812441 | 1730.8    |     66.2591   |    0.0332396 |                  0 |       122.287   |             4.68146   |          0.525 |         0.125 |             9 |     112300   |
# | 11 | 1.2843 |            0 | 0.02467 |             0 |  1.32761  |  785.261  |     44.3392   |    0.0322595 |                  0 |        57.1673  |             3.22791   |          0.775 |         0.125 |             9 |     112300   |
# | 12 | 1.2843 |            0 | 0.02467 |             0 |  2.49945  |  480.328  |     33.1579   |    0.0293602 |                  0 |        19.2106  |             1.32614   |          1.15  |         0.25  |             9 |     112300   |
# | 13 | 1.2843 |            0 | 0.02467 |             0 |  0.831386 |   98.3598 |     15.0391   |    0.0239979 |                  0 |         4.81288 |             0.735884  |          1.65  |         0.25  |             9 |     112300   |
# | 14 | 1.2843 |            0 | 0.02467 |             0 |  1.36975  |  162.471  |     28.9273   |    0.0116853 |                  0 |       129.464   |            23.0505    |          0.15  |         0.05  |            10 |      70810.1 |
# | 15 | 1.2843 |            0 | 0.02467 |             0 |  1.15284  |  441.905  |     43.5659   |    0.0303124 |                  0 |       135.745   |            13.3826    |          0.25  |         0.05  |            10 |      70810.1 |
# | 16 | 1.2843 |            0 | 0.02467 |             0 |  1.30789  |  390.477  |     37.7093   |    0.0331487 |                  0 |       109.684   |            10.5925    |          0.35  |         0.05  |            10 |      70810.1 |
# | 17 | 1.2843 |            0 | 0.02467 |             0 |  1.59452  |  863.035  |     50.6847   |    0.034537  |                  0 |        93.072   |             5.46597   |          0.525 |         0.125 |            10 |      70810.1 |
# | 18 | 1.2843 |            0 | 0.02467 |             0 |  0.423746 |  399.149  |     33.981    |    0.0342613 |                  0 |        43.3916  |             3.69408   |          0.775 |         0.125 |            10 |      70810.1 |
# | 19 | 1.2843 |            0 | 0.02467 |             0 |  0.578392 |  264.341  |     25.428    |    0.0322848 |                  0 |        15.248   |             1.46676   |          1.15  |         0.25  |            10 |      70810.1 |
# | 20 | 1.2843 |            0 | 0.02467 |             0 |  1.54169  |   93.4762 |      1.58353  |    0.0278217 |                  0 |         6.25695 |             0.105996  |          1.65  |         0.25  |            10 |      70810.1 |
# | 21 | 1.2843 |            0 | 0.02467 |             0 |  1.72243  |   93.4628 |    307.043    |    0.0108868 |                  0 |        94.1235  |           309.214     |          0.15  |         0.05  |            11 |      60138   |
# | 22 | 1.2843 |            0 | 0.02467 |             0 |  2.21785  |  316.216  |     37.3193   |    0.028749  |                  0 |       120.593   |            14.2322    |          0.25  |         0.05  |            11 |      60138   |
# | 23 | 1.2843 |            0 | 0.02467 |             0 |  1.01138  |  312.817  |     43.219    |    0.0318048 |                  0 |       107.835   |            14.8985    |          0.35  |         0.05  |            11 |      60138   |
# | 24 | 1.2843 |            0 | 0.02467 |             0 |  0.779631 |  632.119  |     44.9054   |    0.0341186 |                  0 |        81.2509  |             5.77203   |          0.525 |         0.125 |            11 |      60138   |
# | 25 | 1.2843 |            0 | 0.02467 |             0 |  1.01092  |  349.581  |     29.1089   |    0.0347003 |                  0 |        44.181   |             3.67887   |          0.775 |         0.125 |            11 |      60138   |
# | 26 | 1.2843 |            0 | 0.02467 |             0 |  1.12021  |  215.716  |     22.3634   |    0.0331362 |                  0 |        14.2748  |             1.47988   |          1.15  |         0.25  |            11 |      60138   |
# | 27 | 1.2843 |            0 | 0.02467 |             0 |  2.61425  |   93.473  |      0.717391 |    0.0302561 |                  0 |         6.7743  |             0.0519917 |          1.65  |         0.25  |            11 |      60138   |

# %%
clas_filename = '/work/halld/home/viducic/scripts/plotting/dnp_maui/clas_data.csv'
clas_df = pd.read_csv(clas_filename)
for complex_col in ["t", "dsigma_dt", "clas_error", "error_t"]:
    clas_df[complex_col] = clas_df[complex_col].apply(lambda x: x[1:-5])
for col in clas_df.columns:
    clas_df[col] = clas_df[col].astype('Float64')
# clas_df['error_t'] = clas_df['clas_error'].apply(lambda x: abs(x))
clas_df = clas_df[clas_df['t'] < 1.9]
clas_df = clas_df[clas_df['w'] >= 2.45]
clas_300 = clas_df[(clas_df['w'] == 2.55)]
clas_325 = clas_df[(clas_df['w'] == 2.65)]
clas_350 = clas_df[(clas_df['w'] == 2.75)]

# %%
print(clas_df.to_markdown())
# Out:
# |    |   Unnamed: 0 |    w |   cosThetaCM |   e_gam |        t |   dsigma_domega |   dsigma_dt |   clas_error |   error_t |
# |---:|-------------:|-----:|-------------:|--------:|---------:|----------------:|------------:|-------------:|----------:|
# | 10 |           10 | 2.45 |        -0.5  | 2.72957 | 1.77135  |            6.42 |    40.2072  |     1.22674  |   7.68286 |
# | 11 |           11 | 2.45 |        -0.3  | 2.72957 | 1.55831  |            6.39 |    40.0193  |     1.46263  |   9.1602  |
# | 12 |           12 | 2.45 |        -0.1  | 2.72957 | 1.34528  |            5.73 |    35.8859  |     0.890449 |   5.57671 |
# | 13 |           13 | 2.45 |         0.1  | 2.72957 | 1.13224  |            7.29 |    45.6559  |     1.16276  |   7.28211 |
# | 14 |           14 | 2.45 |         0.3  | 2.72957 | 0.9192   |            8.1  |    50.7287  |     2.04978  |  12.8374  |
# | 15 |           15 | 2.45 |         0.5  | 2.72957 | 0.706161 |            6.58 |    41.2093  |     1.31529  |   8.23744 |
# | 16 |           16 | 2.45 |         0.7  | 2.72957 | 0.493123 |            6.68 |    41.8355  |     1.56544  |   9.80404 |
# | 17 |           17 | 2.45 |         0.85 | 2.72957 | 0.333344 |            2.16 |    14.4178  |     1.08171  |   7.22031 |
# | 21 |           21 | 2.55 |        -0.1  | 2.99602 | 1.62949  |            5.37 |    26.1709  |     1.51921  |   7.40393 |
# | 22 |           22 | 2.55 |         0.1  | 2.99602 | 1.35671  |            6.57 |    32.0192  |     1.20017  |   5.84906 |
# | 23 |           23 | 2.55 |         0.3  | 2.99602 | 1.08393  |            6.7  |    32.6527  |     1.19867  |   5.84175 |
# | 24 |           24 | 2.55 |         0.5  | 2.99602 | 0.811154 |           12.12 |    59.0673  |     1.27613  |   6.21926 |
# | 25 |           25 | 2.55 |         0.7  | 2.99602 | 0.538374 |            9.7  |    47.2733  |     2.85608  |  13.9192  |
# | 26 |           26 | 2.55 |         0.85 | 2.99602 | 0.333789 |            7.95 |    41.1261  |     1.828    |   9.45644 |
# | 31 |           31 | 2.65 |         0.1  | 3.27312 | 1.59128  |            3.03 |    12.1339  |     0.885438 |   3.54582 |
# | 32 |           32 | 2.65 |         0.3  | 3.27312 | 1.25991  |            4.26 |    17.0596  |     0.961509 |   3.85045 |
# | 33 |           33 | 2.65 |         0.5  | 3.27312 | 0.928546 |            8.4  |    33.6386  |     0.989798 |   3.96374 |
# | 34 |           34 | 2.65 |         0.7  | 3.27312 | 0.597177 |            9.81 |    39.285   |     1.75602  |   7.03213 |
# | 35 |           35 | 2.65 |         0.85 | 3.27312 | 0.34865  |            0.5  |     2.12105 |     2.62366  |  11.1299  |
# | 40 |           40 | 2.75 |         0.1  | 3.56089 | 1.83535  |            1.95 |     6.62578 |     0.47927  |   1.62848 |
# | 41 |           41 | 2.75 |         0.3  | 3.56089 | 1.44521  |            4.01 |    13.6253  |     0.480208 |   1.63167 |
# | 42 |           42 | 2.75 |         0.5  | 3.56089 | 1.05507  |            5.15 |    17.4989  |     1.09659  |   3.72602 |
# | 43 |           43 | 2.75 |         0.7  | 3.56089 | 0.664933 |            9.26 |    31.464   |     2.03037  |   6.89887 |
# | 44 |           44 | 2.75 |         0.85 | 3.56089 | 0.37233  |            5.73 |    20.6006  |     1.76867  |   6.35876 |

# %%
print(pipkmks_df.columns)
# Out:
# Index(['mean', 'mean_error', 'width', 'width_error', 'chi2ndf', 'yield',
#        'yield_error', 'acceptance', 'acceptance_error', 'cross_section',
#        'cross_section_error', 't_bin_middle', 't_bin_width', 'beam_energy',
#        'luminosity'],
#       dtype='object')

# %%
pipkmks_grouped = pipkmks_df.groupby('beam_energy')
pimkpks_grouped = pimkpks_df.groupby('beam_energy')
clas_grouped = clas_df.groupby('w')

# %% [markdown]
# ## $\pi^+K^-K_s$

# %%
pipkmks_graphs = []
legend = ROOT.TLegend(0.6, 0.6, 0.9, 0.9)
comparison_legend = ROOT.TLegend(0.6, 0.6, 0.9, 0.9)
for beam_energy, group in pipkmks_grouped:
    # if beam_energy > 9:
    #     continue
    graph = ROOT.TGraphErrors(len(group.t_bin_middle.to_numpy()), group.t_bin_middle.to_numpy(dtype='d'), group.cross_section.to_numpy(), group.t_bin_width.to_numpy(), group.cross_section_error.to_numpy())
    graph.SetName(f'graph_{beam_energy}')
    graph.SetMarkerColor(ROOT.kBlue)
    graph.SetMarkerStyle(gluex_markers[beam_energy])
    if beam_energy == 11 or beam_energy == 8:
        graph.SetMarkerSize(1.4)
    else:
        graph.SetMarkerSize(1.1)
    graph.SetLineColor(ROOT.kBlue)
    graph.SetLineWidth(2)
    graph.GetXaxis().SetTitle('-t [GeV^{2}]')
    graph.GetYaxis().SetTitle('#frac{d#sigma}{dt} [nb/GeV^{2}]')
    graph.GetYaxis().SetTitleSize(0.05)
    graph.GetXaxis().SetTitleSize(0.05)
    graph.GetYaxis().SetTitleOffset(1.0)
    graph.GetXaxis().SetTitleOffset(0.9)
    legend.AddEntry(graph, 'E_{#gamma} = ' + f'{beam_energy} GeV', 'lfp')
    comparison_legend.AddEntry(graph, 'E_{#gamma} = ' + f'{beam_energy} GeV', 'lfp')
    pipkmks_graphs.append(graph)

# %% [markdown]
# ## $\pi^-K^+K_s$

# %%
pimkpks_graphs = []
legend = ROOT.TLegend(0.6, 0.6, 0.9, 0.9)
comparison_legend = ROOT.TLegend(0.6, 0.6, 0.9, 0.9)
for beam_energy, group in pimkpks_grouped:
    # if beam_energy > 9:
    #     continue
    graph = ROOT.TGraphErrors(len(group.t_bin_middle.to_numpy()), group.t_bin_middle.to_numpy(dtype='d'), group.cross_section.to_numpy(), group.t_bin_width.to_numpy(), group.cross_section_error.to_numpy())
    graph.SetName(f'graph_{beam_energy}')
    graph.SetMarkerColor(ROOT.kRed)
    graph.SetMarkerStyle(gluex_markers[beam_energy])
    if beam_energy == 11 or beam_energy == 8:
        graph.SetMarkerSize(1.4)
    else:
        graph.SetMarkerSize(1.1)
    graph.SetLineColor(ROOT.kRed)
    graph.SetLineWidth(2)
    graph.GetXaxis().SetTitle('-t [GeV^{2}]')
    graph.GetYaxis().SetTitle('#frac{d#sigma}{dt} [nb/GeV^{2}]')
    graph.GetYaxis().SetTitleSize(0.05)
    graph.GetXaxis().SetTitleSize(0.05)
    graph.GetYaxis().SetTitleOffset(0.9)
    graph.GetXaxis().SetTitleOffset(1.0)
    legend.AddEntry(graph, 'E_{#gamma} = ' + f'{beam_energy} GeV', 'lfp')
    comparison_legend.AddEntry(graph, 'E_{#gamma} = ' + f'{beam_energy} GeV', 'lfp')
    pimkpks_graphs.append(graph)

# %%
clas_graphs = []
for w, group in clas_grouped:
    clas_graph = ROOT.TGraphErrors(len(group.t.to_numpy()), group.t.to_numpy(), group.dsigma_dt.to_numpy(), np.zeros(len(group.t.to_numpy())), group.error_t.to_numpy())
    clas_graph.SetName(f'clas_graph_{w}')
    clas_graph.SetMarkerColor(clas_colors[w])
    clas_graph.SetMarkerStyle(clas_markers[w])
    clas_graph.SetLineColor(clas_colors[w])
    clas_graph.SetLineWidth(2)
    clas_graph.GetXaxis().SetTitle('-t [GeV^{2}]')
    clas_graph.GetYaxis().SetTitle('#frac{d#sigma}{dt} [nb/GeV^{2}]')
    clas_graph.GetYaxis().SetTitleSize(0.05)
    clas_graph.GetXaxis().SetTitleSize(0.05)
    clas_graph.GetYaxis().SetTitleOffset(0.9)
    clas_graph.GetXaxis().SetTitleOffset(0.9)
    comparison_legend.AddEntry(clas_graph, 'E_{#gamma} = ' + '{:.2f} GeV'.format(group['e_gam'].values[0]), 'lfp')
    clas_graphs.append(clas_graph)

# %%
theory_graphs = []

for beam in [8, 9, 10, 11]:
    theory_filename = '/work/halld/home/viducic/theory_predictions/t-slope-{}GeVnew.dat'
    theory_df = pd.read_csv(theory_filename.format(beam), delim_whitespace=True)
    theory_df.columns = ['t', 'diff_cs']
    theory_df = theory_df.loc[(theory_df['t'] > 0.35) & (theory_df['t'] < 1.9)]
    theory_graph = ROOT.TGraph(len(theory_df.t.to_numpy()), theory_df.t.to_numpy(), theory_df.diff_cs.to_numpy())
    theory_graph.SetName(f'theory_graph_{beam}')
    theory_graph.SetMarkerColor(theory_colors[beam])
    theory_graph.SetMarkerStyle(theory_markers[beam])
    theory_graph.SetMarkerSize(1.0)
    theory_graphs.append(theory_graph)


theory_filename = '/work/halld/home/viducic/theory_predictions/t-slope-{}GeVnew.dat'
theory_df = pd.read_csv(theory_filename.format(beam), delim_whitespace=True)
theory_df.columns = ['t', 'diff_cs']
theory_df = theory_df.loc[(theory_df['t'] > 0.1) & (theory_df['t'] < 1.9)]

# %%
c = ROOT.TCanvas()
# c.SetLogy()

pipkmks_graphs[0].Draw('AP')
# graphs[0].GetYaxis().SetRangeUser(2, 150)
for graph in pipkmks_graphs[1:]:
    graph.Draw('P')
legend.Draw()
c.Draw()

# %%
c.Clear()
# c.SetLogy()

pipkmks_graphs[0].Draw('AP')
pipkmks_graphs[0].GetYaxis().SetRangeUser(2, 200)
pipkmks_graphs[1].Draw('P')
clas_graphs[-1].Draw('P')
clas_graphs[-2].Draw('P')
clas_graphs[-3].Draw('P')
clas_graphs[-4].Draw('P')
comparison_legend.Draw()
c.Draw()

# %%
c.Clear()
c.SetLogy()

result_legend = ROOT.TLegend(0.7, 0.8, 0.95, 0.95)
result_legend.AddEntry(pipkmks_graphs[0], 'E_{#gamma} = 8 GeV', 'lfp')
result_legend.AddEntry(pipkmks_graphs[1], 'E_{#gamma} = 9 GeV', 'lfp')
# result_legend.AddEntry(clas_graphs[0], ' CLAS - E_{#gamma} = 2.72 GeV', 'lfp')
# result_legend.AddEntry(clas_graphs[1], ' CLAS - E_{#gamma} = 3.0 GeV', 'lfp')
# result_legend.AddEntry(clas_graphs[2], ' CLAS - E_{#gamma} = 3.27 GeV', 'lfp')
# result_legend.AddEntry(clas_graphs[3], ' CLAS - E_{#gamma} = 3.56 GeV', 'lfp')
# result_legend.AddEntry(theory_graphs[0], 'Theory - E_{#gamma} = 8 GeV', 'lfp')
# result_legend.AddEntry(theory_graphs[1], 'Theory - E_{#gamma} = 9 GeV', 'lfp')

theory_graphs[1].GetXaxis().SetTitle('-t [GeV^{2}]')
theory_graphs[1].GetYaxis().SetTitle('#frac{d#sigma}{dt} [nb/GeV^{2}]')
theory_graphs[1].GetYaxis().SetTitleSize(0.05)
theory_graphs[1].GetXaxis().SetTitleSize(0.05)
theory_graphs[1].GetYaxis().SetTitleOffset(0.9)
theory_graphs[1].GetXaxis().SetTitleOffset(0.9)
theory_graphs[1].SetLineColor(ROOT.kBlue)
theory_graphs[1].SetLineWidth(5)
theory_graphs[0].SetLineColor(ROOT.kRed)
theory_graphs[0].SetLineWidth(5)

pipkmks_graphs[0].GetYaxis().SetRangeUser(2.0, 1000)

pipkmks_graphs[0].Draw('AP')
pipkmks_graphs[1].Draw('P')
theory_graphs[1].Draw('L')
theory_graphs[0].Draw('L')
# clas_graphs[0].Draw('P')
# clas_graphs[1].Draw('P')
# clas_graphs[2].Draw('P')
# clas_graphs[3].Draw('P')
result_legend.Draw()
c.Draw()

# %%
c.Clear()

kkpi_legend = ROOT.TLegend(0.7, 0.8, 0.95, 0.95)
kkpi_legend.AddEntry(pipkmks_graphs[0], '#pi^{+}K^{-}K^{-}', 'lfp')
kkpi_legend.AddEntry(pimkpks_graphs[0], '#pi^{-}K^{+}K^{-}', 'lfp')

pipkmks_graphs[0].GetYaxis().SetRangeUser(2.0, 230)

pipkmks_graphs[0].Draw('AP')
pimkpks_graphs[0].Draw('P')

kkpi_legend.Draw()

c.Draw()

# %%
c.Clear()

kkpi_legend = ROOT.TLegend(0.7, 0.8, 0.95, 0.95)
kkpi_legend.AddEntry(pipkmks_graphs[1], '#pi^{+}K^{-}K^{-}', 'lfp')
kkpi_legend.AddEntry(pimkpks_graphs[1], '#pi^{-}K^{+}K^{-}', 'lfp')

pipkmks_graphs[1].GetYaxis().SetRangeUser(2.0, 250)

pipkmks_graphs[1].Draw('AP')
pimkpks_graphs[1].Draw('P')

kkpi_legend.Draw()

c.Draw()

# %%
c.Clear()

kkpi_legend = ROOT.TLegend(0.7, 0.8, 0.95, 0.95)
kkpi_legend.AddEntry(pipkmks_graphs[3], '#pi^{+}K^{-}K^{-}', 'lfp')
kkpi_legend.AddEntry(pimkpks_graphs[3], '#pi^{-}K^{+}K^{-}', 'lfp')

pipkmks_graphs[3].GetYaxis().SetRangeUser(2.0, 160)

pipkmks_graphs[3].Draw('AP')
pimkpks_graphs[3].Draw('P')

kkpi_legend.Draw()

c.Draw()
